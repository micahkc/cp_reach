# %%
import sys
sys.path.append('/home/micah/Research')
import cp_reach as cp
import json
from matplotlib import pyplot as plt
import cp_reach.rover.simple_turn

file = '/home/micah/example/rover_specs2.json'
with open(file, 'r') as file:
    # Load the data from the JSON file
    rover = json.load(file)

fig1, ax1 = plt.subplots(figsize=(6, 6))
cp.rover.simple_turn.emi_disturbance(rover, ax1)
